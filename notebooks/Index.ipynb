# %% [markdown]
# [<img src="../assets/images/Logo.png" width="64" align="center">](https://github.com/a-fuchs/jupyter-micropython-extended-kernel) &emsp;  [README](../README.md) / **Examples**
#
# ---
#
# # Examples
# ## Connecting the Esp32
# * [With the BLE-REPL ⯈](./BLE_REPL.ipynb)
# * [with the Web-REPL ⯈](./Web_REPL.ipynb)
# * [with the Uart-REPL ⯈](./Uart_REPL.ipynb)
#
# ## Examples using the `%%iPython` cell magic
# * [Setting ESP32 real time clock to current date and time](./SampleSettingESP32RealTimeClock.ipynb)
# * [Interact with slider](./SampleInteractWithSlider.ipynb)
