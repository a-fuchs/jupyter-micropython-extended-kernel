# %% [markdown]
# [<img src="./assets/images/Logo.png" width="64" align="center">](https://github.com/a-fuchs/jupyter-micropython-extended-kernel) &emsp;  [README](./README.md) / **Installing the kernel** | [Testing the kernel](./KernelTest.ipynb)
#
# ---
# # Installing the kernel
#
# In the right environment run the following lines, or run the cells below.
# ```bash
# pip install jupyter-micropython-extended-kernel
# python -m jupyter_micropython_extended_kernel.install
# ```
#
# Install the kernel

# %%
# %pip install --upgrade jupyter-micropython-extended-kernel

# %% [markdown]
# and register the kernel within JupyterLab so it can be selected for use in
# notebooks:

# %%
# !python -m jupyter_micropython_extended_kernel.install

# %% [markdown]
# ---
#
# Now You can [test the JuypterLab Micropython extended Kernel](./KernelTest.ipynb).
#
# ---
